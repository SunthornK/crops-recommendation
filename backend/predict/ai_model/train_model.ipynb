# %%
# import pandas as pd
# import numpy as np
# from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
# from sklearn.model_selection import train_test_split
# import pickle
# from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# # Load your dataset (replace with your actual data source)
# data = pd.DataFrame({
#     "temperature": [25, 28, 22, 30, 26],
#     "humidity": [60, 65, 55, 70, 62],
#     "soil_ph": [6.5, 6.0, 6.8, 5.5, 6.2],
#     "rainfall": [100, 120, 80, 150, 90],
#     "moisture": [45.5, 50.0, 40.0, 55.0, 47.0],  # Target for moisture
#     "crop_type": ["wheat", "rice", "maize", "rice", "wheat"]  # Target for crop type
# })

# # Features and targets
# X = data[["temperature", "humidity", "soil_ph", "rainfall"]]
# y_moisture = data["moisture"]
# y_crop = data["crop_type"]

# # Split data for training and testing (optional, for validation)
# X_train, X_test, y_moisture_train, y_moisture_test = train_test_split(X, y_moisture, test_size=0.2, random_state=42)
# _, _, y_crop_train, y_crop_test = train_test_split(X, y_crop, test_size=0.2, random_state=42)

# # Train moisture model (regression)
# moisture_model = RandomForestRegressor(n_estimators=100, random_state=42)
# moisture_model.fit(X_train, y_moisture_train)

# # Train crop type model (classification)
# crop_model = RandomForestClassifier(n_estimators=100, random_state=42)
# crop_model.fit(X_train, y_crop_train)

# # Save the models to files
# with open("moisture_model.pkl", "wb") as f:
#     pickle.dump(moisture_model, f)
# with open("crop_model.pkl", "wb") as f:
#     pickle.dump(crop_model, f)
    


# # Optional: Test the models
# moisture_pred = moisture_model.predict(X_test)
# crop_pred = crop_model.predict(X_test)
# print("Moisture Predictions:", moisture_pred)
# print("Crop Predictions:", crop_pred)

# r2 = r2_score(y_moisture_test, moisture_pred)
# mae = mean_absolute_error(y_moisture_test, moisture_pred)
# mse = mean_squared_error(y_moisture_test, moisture_pred)
# rmse = np.sqrt(mse)


# print("Moisture Prediction Performance:")
# print(f"R² Score: {r2:.4f}")
# print(f"MAE: {mae:.4f}")
# print(f"MSE: {mse:.4f}")
# print(f"RMSE: {rmse:.4f}")
# Out:
# Moisture Predictions: [47.595]
# Crop Predictions: ['wheat']
# Moisture Prediction Performance:
# R² Score: nan
# MAE: 2.4050
# MSE: 5.7840
# RMSE: 2.4050
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1211: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.model_selection import train_test_split
import pickle
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
df = pd.read_csv('data_core_2.csv')
df.head()
# Out:
#    Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0         26.0      52.0      38.0     Sandy      Maize        37          0
# 1         29.0      52.0      45.0     Loamy  Sugarcane        12          0
# 2         34.0      65.0      62.0     Black     Cotton         7          9
# 3         32.0      62.0      34.0       Red    Tobacco        22          0
# 4         28.0      54.0      46.0    Clayey      Paddy        35          0
#
#    Phosphorous Fertilizer Name
# 0            0            Urea
# 1           36             DAP
# 2           30        14-35-14
# 3           20           28-28
# 4            0            Urea

# %%
X_moist = df[["Temparature", "Humidity"]]
y_moisture = df["Moisture"]

X_crop = df[["Temparature", "Humidity", "Moisture"]]
y_crop_type = df["Crop Type"]

# %% [markdown]
# ## Test and Train split

# %%
X_train, X_test, y_moisture_train, y_moisture_test = train_test_split(X, y_moisture, test_size=0.2, random_state=42)
X_train_crop, X_test_crop, y_crop_train, y_crop_test = train_test_split(X_crop, y_crop_type, test_size=0.2, random_state=42)

# %% [markdown]
# ## Train model for Moisture.

# %%
moisture_model = RandomForestRegressor(n_estimators=100, random_state=42)
moisture_model.fit(X_train, y_moisture_train)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# ## Train model for Crop type

# %%
crop_model = RandomForestClassifier(n_estimators=100, random_state=42)
crop_model.fit(X_train_crop, y_crop_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
moisture_pred = moisture_model.predict(X_test)
print("Moisture Predictions:", moisture_pred)
# Out:
# Moisture Predictions: [42.1113 33.6114 38.0441 ... 42.4412 51.0224 43.4216]

# %%
crop_pred = crop_model.predict(X_test_crop)
print("Crop Predictions:", crop_pred)
# Out:
# Crop Predictions: ['Wheat' 'Paddy' 'Wheat' ... 'Cotton' 'Sugarcane' 'Paddy']

# %%
df_sec = pd.read_csv("Secondary_Data.csv")
df_sec
# Out:
#         id            timestamp   temp  humidity  temp_min  temp_max  \
# 0        1  2025-03-25 10:36:46  33.33        64        32        34
# 1        2  2025-03-25 10:36:48  33.33        64        32        34
# 2        3  2025-03-25 10:37:17  33.33        64        32        34
# 3        4  2025-03-25 10:47:09  33.26        63        32        34
# 4        5  2025-03-25 10:57:09  33.81        61        33        34
# ...    ...                  ...    ...       ...       ...       ...
# 2236  2237  2025-04-11 15:06:49  30.64        77        30        33
# 2237  2238  2025-04-11 15:16:49  32.24        72        31        33
# 2238  2239  2025-04-11 15:26:49  32.25        72        31        33
# 2239  2240  2025-04-11 15:36:49  32.43        72        32        34
# 2240  2241  2025-04-11 15:46:49  32.43        72        32        34
#
#       wind_speed weather weather_description      lat       lon      place
# ...

# %%
df_b = df_sec[["temp", "humidity"]].copy()

# Rename to match training data
df_b.rename(columns={
    "temp": "Temparature",
    "humidity": "Humidity"
}, inplace=True)

# Now it should work
moisture_predict_b = moisture_model.predict(df_b)

# %%
df_b["Moisture"] = moisture_predict_b

# %%
crop_type_predict = crop_model.predict(df_b)
crop_type_predict
# Out:
# array(['Sugarcane', 'Sugarcane', 'Sugarcane', ..., 'Tobacco', 'Tobacco',
#        'Tobacco'], dtype=object)

# %% [markdown]
# ## Export Model

# %%
with open("moisture_model.pkl", "wb") as f:
    pickle.dump(moisture_model, f)
with open("crop_model.pkl", "wb") as f:
    pickle.dump(crop_model, f)
